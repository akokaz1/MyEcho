# %%
import numpy as np
import pandas as pd
import math

# %%
cand_uni = raw_input("What univeristy?")
# Out:
# What univeristy?Buckinghamshire New University

# %%
uni_df = pd.read_csv('C:\Users\student01\Desktop\MyEcho\Academia\university\university_ranking_clean\uk_university_ranking.txt', sep = '\t')
uni_df
# Out:
#                                   Rank 2017 - Reversed  Univeristy Name  \
# 0    127  126  London Metropolitan University  247 ...              NaN
# 1    126  124  University of East London  277  3.93...              NaN
# 2    125  123  Wrexham Glyndwr University  236  4.1...              NaN
# 3    124  112  University of St Mark and St John  2...              NaN
# 4    123  125  University of Wales Trinity Saint Da...              NaN
# 5    122  121  University of Bolton  283  4.10  2.0...              NaN
# 6    121  111  University of Cumbria  286  3.93  2....              NaN
# 7    120  110  University of Bedfordshire  234  4.0...              NaN
# 8    119  117  Bishop Grosseteste University  284  ...              NaN
# 9    118  109  St Mary's University, Twickenham  29...              NaN
# 10   117  120  Newman University  298  4.15  2.13  ...              NaN
# 11   115  119  London South Bank University  254  3...              NaN
# ...
